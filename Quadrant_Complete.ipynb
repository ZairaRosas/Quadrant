# %%
import pandas as pd
from pandas import read_csv
import geopandas as gpd
from geopandas import GeoDataFrame
from shapely.geometry import Point, LineString, shape
from glob import glob

# %%
file_names = glob(r'F:\Quadrant_prueba\part-00*.csv')

# %%
list = []

# %%
for file_name in file_names:
    df = read_csv(file_name, names = ['Device_ID', 'Lat', 'Lon', 'GPS_Accu', 'Timestamp', 'IP', 'OS_ID', 'OS', 'Country', 'Quad_ID', 'Publisher'], low_memory=False)
    list.append(df)

# %%
frame = pd.concat(list, axis=0, ignore_index=True)
frame
# Out:
#                                      Device_ID        Lat        Lon  \
# 0         0EED4050-5117-4BC8-AB2D-6504FB5E9BA9  25.946060  -97.46815
# 1         8ded0000-66e2-4854-99d8-860a24eb7043  38.722200  -77.10740
# 2         daf49549-bf67-4f33-a727-9fbe4bccfa6a  39.916622  -85.38707
# 3         C779F7A2-4139-44C5-AF31-512D7CD13210  41.168198  -73.26890
# 4         ec0dba7e-7e25-4482-84e2-0e6d3465f51f  34.216217 -118.59902
# ...                                        ...        ...        ...
# 31378687  cab4bdc4-c0bd-4e96-b85e-84ebdcf549d9  26.270267  -81.74566
# 31378688  c9e9481a-42f1-4d7e-8705-989e67cc8c94  39.177140 -110.33839
# 31378689  9d272483-2393-46be-b33b-b2c993e35b31  22.771519 -102.57101
# 31378690  5ddb2a8a-6c2e-4a6a-9335-a9899326a7d2  38.865330  -77.40082
# 31378691  c9e9481a-42f1-4d7e-8705-989e67cc8c94  39.175686 -110.33837
#
#           GPS_Accu      Timestamp              IP OS_ID       OS Country  \
# 0              6.0  1569480606000  172.58.101.127  idfa      iOS      US
# 1           4811.0  1569480606000  96.255.244.230  aaid  Android      US
# 2             19.0  1569480606000   99.203.78.197  aaid  Android      US
# 3              4.0  1569480607000    67.81.251.92  idfa      iOS      US
# 4           1316.0  1569480607000    69.75.177.51  aaid  Android      US
# ...            ...            ...             ...   ...      ...     ...
# 31378687      14.0  1570037476000             NaN  aaid  Android      US
# 31378688       3.0  1570037477000             NaN  aaid  Android      US
# 31378689       5.0  1570037478000             NaN  aaid  Android      MX
# 31378690      14.0  1570037481000             NaN  aaid  Android      US
# 31378691       3.0  1570037482000             NaN  aaid  Android      US
#
#           Quad_ID                         Publisher
# 0              24  ebd8eceafe1479f86f75e2f54d6aac77
# 1              24  ebd8eceafe1479f86f75e2f54d6aac77
# 2              24  ebd8eceafe1479f86f75e2f54d6aac77
# 3              24  ebd8eceafe1479f86f75e2f54d6aac77
# 4              24  ebd8eceafe1479f86f75e2f54d6aac77
# ...           ...                               ...
# 31378687       24  907602dad23f9b70a59dbfe7c62f0be1
# 31378688       24  907602dad23f9b70a59dbfe7c62f0be1
# 31378689       24  907602dad23f9b70a59dbfe7c62f0be1
# 31378690       24  907602dad23f9b70a59dbfe7c62f0be1
# 31378691       24  907602dad23f9b70a59dbfe7c62f0be1
#
# [31378692 rows x 11 columns]

# %%
df = frame[frame['Country'] == 'MX']
df
# Out:
#                                      Device_ID        Lat         Lon  \
# 9022815   9145C545-F6AC-4E45-88A5-FE7102CDA727  32.502700 -117.003700
# 9023117   65ae6dd5-a4f7-4d11-b197-5b1bfa1fa6cf  28.702420 -106.094170
# 9023143   8093e8e5-8564-4084-ac38-e6c825dfbbf5  25.789799 -100.168880
# 9023293   038981a8-90e7-49ac-a859-6c9e38f7a036  20.977324  -89.624940
# 9023584   3ad65075-f6d5-4c24-ac1f-98509188dda5  31.036507 -114.834970
# ...                                        ...        ...         ...
# 31378668  9d272483-2393-46be-b33b-b2c993e35b31  22.771526 -102.570984
# 31378676  9d272483-2393-46be-b33b-b2c993e35b31  22.771526 -102.570984
# 31378680  47aaf82a-c637-44ef-b6e3-8635ad76759d  19.993860 -102.282290
# 31378684  9d272483-2393-46be-b33b-b2c993e35b31  22.771526 -102.570984
# 31378689  9d272483-2393-46be-b33b-b2c993e35b31  22.771519 -102.571010
#
#           GPS_Accu      Timestamp               IP OS_ID       OS Country  \
# 9022815       15.0  1569998755000   187.250.54.140  idfa      iOS      MX
# 9023117       15.0  1569998775000   177.236.12.119  aaid  Android      MX
# 9023143        9.0  1569998777000    200.68.141.43  aaid  Android      MX
# 9023293        8.0  1569998787000  177.237.146.109  aaid  Android      MX
# 9023584       10.0  1569998803000   189.222.36.227  aaid  Android      MX
# ...            ...            ...              ...   ...      ...     ...
# 31378668       5.0  1570037463000              NaN  aaid  Android      MX
# 31378676       5.0  1570037468000              NaN  aaid  Android      MX
# 31378680      17.0  1570037471000              NaN  aaid  Android      MX
# 31378684      20.0  1570037473000              NaN  aaid  Android      MX
# 31378689       5.0  1570037478000              NaN  aaid  Android      MX
#
#           Quad_ID                         Publisher
# 9022815        24  ebd8eceafe1479f86f75e2f54d6aac77
# 9023117        24  ebd8eceafe1479f86f75e2f54d6aac77
# 9023143        24  ebd8eceafe1479f86f75e2f54d6aac77
# 9023293        24  ebd8eceafe1479f86f75e2f54d6aac77
# 9023584        24  ebd8eceafe1479f86f75e2f54d6aac77
# ...           ...                               ...
# 31378668       24  907602dad23f9b70a59dbfe7c62f0be1
# 31378676       24  907602dad23f9b70a59dbfe7c62f0be1
# 31378680       24  907602dad23f9b70a59dbfe7c62f0be1
# 31378684       24  907602dad23f9b70a59dbfe7c62f0be1
# 31378689       24  907602dad23f9b70a59dbfe7c62f0be1
#
# [957288 rows x 11 columns]

# %%
df['Timestamp1'] = df['Timestamp'].astype(str)
df['Timestamp1'] = df['Timestamp1'].str[:10]
df['Timestamp1'] = pd.to_datetime(df['Timestamp1'], unit='s')
df
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\python37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                      Device_ID        Lat         Lon  \
# 9022815   9145C545-F6AC-4E45-88A5-FE7102CDA727  32.502700 -117.003700
# 9023117   65ae6dd5-a4f7-4d11-b197-5b1bfa1fa6cf  28.702420 -106.094170
# 9023143   8093e8e5-8564-4084-ac38-e6c825dfbbf5  25.789799 -100.168880
# 9023293   038981a8-90e7-49ac-a859-6c9e38f7a036  20.977324  -89.624940
# 9023584   3ad65075-f6d5-4c24-ac1f-98509188dda5  31.036507 -114.834970
# ...                                        ...        ...         ...
# 31378668  9d272483-2393-46be-b33b-b2c993e35b31  22.771526 -102.570984
# 31378676  9d272483-2393-46be-b33b-b2c993e35b31  22.771526 -102.570984
# 31378680  47aaf82a-c637-44ef-b6e3-8635ad76759d  19.993860 -102.282290
# 31378684  9d272483-2393-46be-b33b-b2c993e35b31  22.771526 -102.570984
# 31378689  9d272483-2393-46be-b33b-b2c993e35b31  22.771519 -102.571010
#
#           GPS_Accu      Timestamp               IP OS_ID       OS Country  \
# 9022815       15.0  1569998755000   187.250.54.140  idfa      iOS      MX
# 9023117       15.0  1569998775000   177.236.12.119  aaid  Android      MX
# 9023143        9.0  1569998777000    200.68.141.43  aaid  Android      MX
# 9023293        8.0  1569998787000  177.237.146.109  aaid  Android      MX
# 9023584       10.0  1569998803000   189.222.36.227  aaid  Android      MX
# ...            ...            ...              ...   ...      ...     ...
# 31378668       5.0  1570037463000              NaN  aaid  Android      MX
# 31378676       5.0  1570037468000              NaN  aaid  Android      MX
# 31378680      17.0  1570037471000              NaN  aaid  Android      MX
# 31378684      20.0  1570037473000              NaN  aaid  Android      MX
# 31378689       5.0  1570037478000              NaN  aaid  Android      MX
#
#           Quad_ID                         Publisher          Timestamp1
# 9022815        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:45:55
# 9023117        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:46:15
# 9023143        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:46:17
# 9023293        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:46:27
# 9023584        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:46:43
# ...           ...                               ...                 ...
# 31378668       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:03
# 31378676       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:08
# 31378680       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:11
# 31378684       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:13
# 31378689       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:18
#
# [957288 rows x 12 columns]

# %%
#Para pasar en formato date
df['Timestamp2'] = df['Timestamp1'].values.astype('datetime64[D]')

#Lo queremos en formato str
df['Timestamp2'] = df['Timestamp1'].astype(str)
df['Timestamp2'] = df['Timestamp2'].str[:10]
df
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\python37\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# c:\python37\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                      Device_ID        Lat         Lon  \
# 9022815   9145C545-F6AC-4E45-88A5-FE7102CDA727  32.502700 -117.003700
# 9023117   65ae6dd5-a4f7-4d11-b197-5b1bfa1fa6cf  28.702420 -106.094170
# 9023143   8093e8e5-8564-4084-ac38-e6c825dfbbf5  25.789799 -100.168880
# 9023293   038981a8-90e7-49ac-a859-6c9e38f7a036  20.977324  -89.624940
# 9023584   3ad65075-f6d5-4c24-ac1f-98509188dda5  31.036507 -114.834970
# ...                                        ...        ...         ...
# 31378668  9d272483-2393-46be-b33b-b2c993e35b31  22.771526 -102.570984
# 31378676  9d272483-2393-46be-b33b-b2c993e35b31  22.771526 -102.570984
# 31378680  47aaf82a-c637-44ef-b6e3-8635ad76759d  19.993860 -102.282290
# 31378684  9d272483-2393-46be-b33b-b2c993e35b31  22.771526 -102.570984
# 31378689  9d272483-2393-46be-b33b-b2c993e35b31  22.771519 -102.571010
#
#           GPS_Accu      Timestamp               IP OS_ID       OS Country  \
# 9022815       15.0  1569998755000   187.250.54.140  idfa      iOS      MX
# 9023117       15.0  1569998775000   177.236.12.119  aaid  Android      MX
# 9023143        9.0  1569998777000    200.68.141.43  aaid  Android      MX
# 9023293        8.0  1569998787000  177.237.146.109  aaid  Android      MX
# 9023584       10.0  1569998803000   189.222.36.227  aaid  Android      MX
# ...            ...            ...              ...   ...      ...     ...
# 31378668       5.0  1570037463000              NaN  aaid  Android      MX
# 31378676       5.0  1570037468000              NaN  aaid  Android      MX
# 31378680      17.0  1570037471000              NaN  aaid  Android      MX
# 31378684      20.0  1570037473000              NaN  aaid  Android      MX
# 31378689       5.0  1570037478000              NaN  aaid  Android      MX
#
#           Quad_ID                         Publisher          Timestamp1  \
# 9022815        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:45:55
# 9023117        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:46:15
# 9023143        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:46:17
# 9023293        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:46:27
# 9023584        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:46:43
# ...           ...                               ...                 ...
# 31378668       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:03
# 31378676       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:08
# 31378680       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:11
# 31378684       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:13
# 31378689       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:18
#
#           Timestamp2
# 9022815   2019-10-02
# 9023117   2019-10-02
# 9023143   2019-10-02
# 9023293   2019-10-02
# 9023584   2019-10-02
# ...              ...
# 31378668  2019-10-02
# 31378676  2019-10-02
# 31378680  2019-10-02
# 31378684  2019-10-02
# 31378689  2019-10-02
#
# [957288 rows x 13 columns]

# %%
df['AvantiID'] = df['Device_ID'] + df['Timestamp2']
df
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                      Device_ID        Lat         Lon  \
# 9022815   9145C545-F6AC-4E45-88A5-FE7102CDA727  32.502700 -117.003700
# 9023117   65ae6dd5-a4f7-4d11-b197-5b1bfa1fa6cf  28.702420 -106.094170
# 9023143   8093e8e5-8564-4084-ac38-e6c825dfbbf5  25.789799 -100.168880
# 9023293   038981a8-90e7-49ac-a859-6c9e38f7a036  20.977324  -89.624940
# 9023584   3ad65075-f6d5-4c24-ac1f-98509188dda5  31.036507 -114.834970
# ...                                        ...        ...         ...
# 31378668  9d272483-2393-46be-b33b-b2c993e35b31  22.771526 -102.570984
# 31378676  9d272483-2393-46be-b33b-b2c993e35b31  22.771526 -102.570984
# 31378680  47aaf82a-c637-44ef-b6e3-8635ad76759d  19.993860 -102.282290
# 31378684  9d272483-2393-46be-b33b-b2c993e35b31  22.771526 -102.570984
# 31378689  9d272483-2393-46be-b33b-b2c993e35b31  22.771519 -102.571010
#
#           GPS_Accu      Timestamp               IP OS_ID       OS Country  \
# 9022815       15.0  1569998755000   187.250.54.140  idfa      iOS      MX
# 9023117       15.0  1569998775000   177.236.12.119  aaid  Android      MX
# 9023143        9.0  1569998777000    200.68.141.43  aaid  Android      MX
# 9023293        8.0  1569998787000  177.237.146.109  aaid  Android      MX
# 9023584       10.0  1569998803000   189.222.36.227  aaid  Android      MX
# ...            ...            ...              ...   ...      ...     ...
# 31378668       5.0  1570037463000              NaN  aaid  Android      MX
# 31378676       5.0  1570037468000              NaN  aaid  Android      MX
# 31378680      17.0  1570037471000              NaN  aaid  Android      MX
# 31378684      20.0  1570037473000              NaN  aaid  Android      MX
# 31378689       5.0  1570037478000              NaN  aaid  Android      MX
#
#           Quad_ID                         Publisher          Timestamp1  \
# 9022815        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:45:55
# 9023117        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:46:15
# 9023143        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:46:17
# 9023293        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:46:27
# 9023584        24  ebd8eceafe1479f86f75e2f54d6aac77 2019-10-02 06:46:43
# ...           ...                               ...                 ...
# 31378668       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:03
# 31378676       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:08
# 31378680       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:11
# 31378684       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:13
# 31378689       24  907602dad23f9b70a59dbfe7c62f0be1 2019-10-02 17:31:18
#
#           Timestamp2                                        AvantiID
# 9022815   2019-10-02  9145C545-F6AC-4E45-88A5-FE7102CDA7272019-10-02
# 9023117   2019-10-02  65ae6dd5-a4f7-4d11-b197-5b1bfa1fa6cf2019-10-02
# 9023143   2019-10-02  8093e8e5-8564-4084-ac38-e6c825dfbbf52019-10-02
# 9023293   2019-10-02  038981a8-90e7-49ac-a859-6c9e38f7a0362019-10-02
# 9023584   2019-10-02  3ad65075-f6d5-4c24-ac1f-98509188dda52019-10-02
# ...              ...                                             ...
# 31378668  2019-10-02  9d272483-2393-46be-b33b-b2c993e35b312019-10-02
# 31378676  2019-10-02  9d272483-2393-46be-b33b-b2c993e35b312019-10-02
# 31378680  2019-10-02  47aaf82a-c637-44ef-b6e3-8635ad76759d2019-10-02
# 31378684  2019-10-02  9d272483-2393-46be-b33b-b2c993e35b312019-10-02
# 31378689  2019-10-02  9d272483-2393-46be-b33b-b2c993e35b312019-10-02
#
# [957288 rows x 14 columns]

# %%
df.to_csv(r'F:\Quadrant_prueba\prueba.csv')
