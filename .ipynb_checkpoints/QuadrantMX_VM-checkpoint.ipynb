# %% [markdown]
# <h1>Proecso para 10 archivos de Quadrant al mismo tiempo<h1>

# %%
import pandas as pd
from pandas import read_csv
import geopandas as gpd
from geopandas import GeoDataFrame
from shapely.geometry import Point, LineString, shape
from glob import glob

# %%
file_names = glob(r'F:\Quadrant_Sin_comprimir\02\part-0002*.csv')

# %%
list = []

# %%
for file_name in file_names:
    df = read_csv(file_name, names = ['Device_ID', 'Lat', 'Lon', 'GPS_Accu', 'Timestamp', 'IP', 'OS_ID', 'OS', 'Country', 'Quad_ID', 'Publisher'], low_memory=False)
    list.append(df)

# %%
frame = pd.concat(list, axis=0, ignore_index=True)
frame
# Out:
#                                      Device_ID        Lat         Lon  \
# 0         80390cd2-ca86-4167-82d9-57c19f1d1f48  34.072070 -118.266330
# 1         56e11f90-ba8c-4fb9-aec5-5ae21599f99d  40.912100  -74.174800
# 2         8DE17553-B27C-430D-9B89-28948B1C970A  29.922700  -95.493900
# 3         FBBB9796-CA9D-4A55-A61D-2094CF70B9B7  29.862700  -95.584600
# 4         0B6407B1-3196-44BC-BA63-15A148FEE941  29.165700  -82.127300
# ...                                        ...        ...         ...
# 62237899  86f409eb-1118-40d1-adf3-3bafc04c3549  37.314407 -121.999405
# 62237900  965bb2a0-92f4-4977-a2d0-d5987266c0bf  41.763930  -87.900130
# 62237901  36df6f58-c9fc-4fdb-b025-b0063101a4c0  35.941350  -84.070660
# 62237902  86f409eb-1118-40d1-adf3-3bafc04c3549  37.314407 -121.999405
# 62237903  2bc74cc1-9e72-4f40-88ba-b06356b886d3  48.515274 -122.609886
#
#           GPS_Accu      Timestamp              IP OS_ID       OS Country  \
# ...

# %%
df = frame[frame['Country'] == 'MX']
df
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-6-0b81d5e8cebf> in <module>
# ----> 1 df = frame[frame['Country'] == 'MX']
#       2 df
#
# d:\programs\python39\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3013         # Do we have a (boolean) 1d indexer?
#    3014         if com.is_bool_indexer(key):
# -> 3015             return self._getitem_bool_array(key)
#    3016
#    3017         # We are left with two options: a single key, and a collection of keys,
#
# d:\programs\python39\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3068         key = check_bool_indexer(self.index, key)
#    3069         indexer = key.nonzero()[0]
# -> 3070         return self._take_with_is_copy(indexer, axis=0)
#    3071
#    3072     def _getitem_multilevel(self, key):
#
# ...

# %%
df['Timestamp1'] = df['Timestamp'].astype(str)
df['Timestamp1'] = df['Timestamp1'].str[:10]
df['Timestamp1'] = pd.to_datetime(df['Timestamp1'], unit='s')
df

# %%
#Para pasar en formato date
df['Timestamp2'] = df['Timestamp1'].values.astype('datetime64[D]')

#Lo queremos en formato str
df['Timestamp2'] = df['Timestamp1'].astype(str)
df['Timestamp2'] = df['Timestamp2'].str[:10]
df

# %%
df.loc['AvantiID'] = df.loc['Device_ID'] + df.loc['Timestamp2']
df

# %%
df.to_csv(r'F:\Quadrant_prueba\quadrant_parte0002_completo.csv')
