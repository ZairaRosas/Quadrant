# %%
from pandas import read_csv

# %%
file = read_csv(r'F:\Quadrant\Procesos\DescargasBigQuery\20210528_Torreon_Matamoros\DespuesPython\Quadrant_Matamoros_Torreon.csv')
file
# Out:
#           Unnamed: 0                             Device_ID        Lat  \
# 0                  0  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593960
# 1                  1  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593920
# 2                  2  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515417
# 3                  3  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515432
# 4                  4  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515432
# ...              ...                                   ...        ...
# 13613812     1361638  bfe3d696-a67c-44e0-99a2-77748834c6eb  25.550000
# 13613813     1361639  bfe3d696-a67c-44e0-99a2-77748834c6eb  25.550000
# 13613814     1361640  34c1a55e-6f7e-406e-8399-55b674a1f76f  25.550000
# 13613815     1361641  d604ca18-b84d-47b0-8447-1c962ce6bbf6  25.550000
# 13613816     1361642  d604ca18-b84d-47b0-8447-1c962ce6bbf6  25.550000
#
#                  Lon  GPS_Accu      Timestamp               IP OS_ID       OS  \
# ...

# %%
file_drop = file.drop_duplicates(subset=['Device_ID', 'Lat', 'Lon', 'Timestamp', 'OS'])

# %%
file_drop
# Out:
#           Unnamed: 0                             Device_ID        Lat  \
# 0                  0  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593960
# 1                  1  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593920
# 2                  2  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515417
# 3                  3  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515432
# 4                  4  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515432
# ...              ...                                   ...        ...
# 13613811     1361637  9510a7c7-4131-4b8c-85a4-2f55d4e370d2  25.550000
# 13613812     1361638  bfe3d696-a67c-44e0-99a2-77748834c6eb  25.550000
# 13613814     1361640  34c1a55e-6f7e-406e-8399-55b674a1f76f  25.550000
# 13613815     1361641  d604ca18-b84d-47b0-8447-1c962ce6bbf6  25.550000
# 13613816     1361642  d604ca18-b84d-47b0-8447-1c962ce6bbf6  25.550000
#
#                  Lon  GPS_Accu      Timestamp               IP OS_ID       OS  \
# ...

# %%
df01 = file_drop[file_drop['Timestamp2'] == '2019-10-01']
df02 = file_drop[file_drop['Timestamp2'] == '2019-10-02']
df03 = file_drop[file_drop['Timestamp2'] == '2019-10-03']
df04 = file_drop[file_drop['Timestamp2'] == '2019-10-04']
df05 = file_drop[file_drop['Timestamp2'] == '2019-10-05']
df06 = file_drop[file_drop['Timestamp2'] == '2019-10-06']
df07 = file_drop[file_drop['Timestamp2'] == '2019-10-07']
df08 = file_drop[file_drop['Timestamp2'] == '2019-10-08']
df09 = file_drop[file_drop['Timestamp2'] == '2019-10-09']
df10 = file_drop[file_drop['Timestamp2'] == '2019-10-10']
df11 = file_drop[file_drop['Timestamp2'] == '2019-10-11']
df12 = file_drop[file_drop['Timestamp2'] == '2019-10-12']
df13 = file_drop[file_drop['Timestamp2'] == '2019-10-13']
df14 = file_drop[file_drop['Timestamp2'] == '2019-10-14']
df15 = file_drop[file_drop['Timestamp2'] == '2019-10-15']
df16 = file_drop[file_drop['Timestamp2'] == '2019-10-16']
df17 = file_drop[file_drop['Timestamp2'] == '2019-10-17']
df18 = file_drop[file_drop['Timestamp2'] == '2019-10-18']
df19 = file_drop[file_drop['Timestamp2'] == '2019-10-19']
df20 = file_drop[file_drop['Timestamp2'] == '2019-10-20']
df21 = file_drop[file_drop['Timestamp2'] == '2019-10-21']
df22 = file_drop[file_drop['Timestamp2'] == '2019-10-22']
df23 = file_drop[file_drop['Timestamp2'] == '2019-10-23']
df24 = file_drop[file_drop['Timestamp2'] == '2019-10-24']
df25 = file_drop[file_drop['Timestamp2'] == '2019-10-25']
df26 = file_drop[file_drop['Timestamp2'] == '2019-10-26']
df27 = file_drop[file_drop['Timestamp2'] == '2019-10-27']
df28 = file_drop[file_drop['Timestamp2'] == '2019-10-28']
df29 = file_drop[file_drop['Timestamp2'] == '2019-10-29']
df30 = file_drop[file_drop['Timestamp2'] == '2019-10-30']
df31 = file_drop[file_drop['Timestamp2'] == '2019-10-31']
# Out:
#           Unnamed: 0                             Device_ID        Lat  \
# 475              475  09e8660f-daac-4981-bdf0-677ecca96fe3  25.554320
# 476              476  84ee26c3-7e43-41e8-99ff-16c4a443b6b8  25.538788
# 477              477  5a2923a0-e65a-461e-ac67-1489d7278d5d  25.532360
# 478              478  f75da3ba-c824-4ca0-ac3b-cb809527df8e  25.604029
# 479              479  184f4a46-e2d4-4e8e-aa8a-4eab5868ce60  25.577810
# ...              ...                                   ...        ...
# 13607977     1355803  9ae03555-4bae-4d97-b732-ab6dd73b1813  25.604060
# 13607978     1355804  6f3da1b2-1dce-4c28-b812-40e468ba561f  25.594656
# 13607982     1355808  d2db5f42-35a2-4b86-ab20-b8d1a2569b11  25.518353
# 13607987     1355813  02bd2e26-2a10-4d92-a169-c25b49e88fcc  25.523834
# 13607988     1355814  8ddcbedf-efc2-4eb5-ba23-d527f38697cc  25.533201
#
#                  Lon  GPS_Accu      Timestamp  \
# 475      -103.464670    16.687  1569954239000
# ...
