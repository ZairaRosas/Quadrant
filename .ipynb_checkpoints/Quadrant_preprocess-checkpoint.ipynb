# %% [markdown]
# <h1>Preceso para descarga de Quadrant<h1>

# %%
import pandas as pd
from pandas import read_csv

# %%
file00 = read_csv(r'F:\Quadrant\Procesos\DescargasBigQuery\20210528_Torreon_Matamoros\Originales\uadrant_Torreon_Matamoros_20210528_parte000000000000.csv')
file01 = read_csv(r'F:\Quadrant\Procesos\DescargasBigQuery\20210528_Torreon_Matamoros\Originales\uadrant_Torreon_Matamoros_20210528_parte000000000001.csv')
file02 = read_csv(r'F:\Quadrant\Procesos\DescargasBigQuery\20210528_Torreon_Matamoros\Originales\uadrant_Torreon_Matamoros_20210528_parte000000000002.csv')
file03 = read_csv(r'F:\Quadrant\Procesos\DescargasBigQuery\20210528_Torreon_Matamoros\Originales\uadrant_Torreon_Matamoros_20210528_parte000000000003.csv')
file04 = read_csv(r'F:\Quadrant\Procesos\DescargasBigQuery\20210528_Torreon_Matamoros\Originales\uadrant_Torreon_Matamoros_20210528_parte000000000004.csv')
file05 = read_csv(r'F:\Quadrant\Procesos\DescargasBigQuery\20210528_Torreon_Matamoros\Originales\uadrant_Torreon_Matamoros_20210528_parte000000000005.csv')
file06 = read_csv(r'F:\Quadrant\Procesos\DescargasBigQuery\20210528_Torreon_Matamoros\Originales\uadrant_Torreon_Matamoros_20210528_parte000000000006.csv')
file07 = read_csv(r'F:\Quadrant\Procesos\DescargasBigQuery\20210528_Torreon_Matamoros\Originales\uadrant_Torreon_Matamoros_20210528_parte000000000007.csv')
file08 = read_csv(r'F:\Quadrant\Procesos\DescargasBigQuery\20210528_Torreon_Matamoros\Originales\uadrant_Torreon_Matamoros_20210528_parte000000000008.csv')
file09 = read_csv(r'F:\Quadrant\Procesos\DescargasBigQuery\20210528_Torreon_Matamoros\Originales\uadrant_Torreon_Matamoros_20210528_parte000000000009.csv')
# Out:
#           Unnamed: 0                             Device_ID        Lat  \
# 0                  0  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593960
# 1                  1  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593920
# 2                  2  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515417
# 3                  3  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515432
# 4                  4  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515432
# ...              ...                                   ...        ...
# 13613812     1361638  bfe3d696-a67c-44e0-99a2-77748834c6eb  25.550000
# 13613813     1361639  bfe3d696-a67c-44e0-99a2-77748834c6eb  25.550000
# 13613814     1361640  34c1a55e-6f7e-406e-8399-55b674a1f76f  25.550000
# 13613815     1361641  d604ca18-b84d-47b0-8447-1c962ce6bbf6  25.550000
# 13613816     1361642  d604ca18-b84d-47b0-8447-1c962ce6bbf6  25.550000
#
#                  Lon  GPS_Accu      Timestamp               IP OS_ID       OS  \
# ...

# %%
file = pd.concat([file00, file01, file02, file03, file04, file05, file06, file07, file08, file09])

# %%
file['TS_Central'] = pd.to_datetime(file['Timestamp'],  unit='ms')
file['TS_Central'] = file['TS_Central'].dt.tz_localize('UTC').dt.tz_convert('US/Central')
file
# Out:
#           Unnamed: 0                             Device_ID        Lat  \
# 0                  0  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593960
# 1                  1  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593920
# 2                  2  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515417
# 3                  3  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515432
# 4                  4  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515432
# ...              ...                                   ...        ...
# 13613812     1361638  bfe3d696-a67c-44e0-99a2-77748834c6eb  25.550000
# 13613813     1361639  bfe3d696-a67c-44e0-99a2-77748834c6eb  25.550000
# 13613814     1361640  34c1a55e-6f7e-406e-8399-55b674a1f76f  25.550000
# 13613815     1361641  d604ca18-b84d-47b0-8447-1c962ce6bbf6  25.550000
# 13613816     1361642  d604ca18-b84d-47b0-8447-1c962ce6bbf6  25.550000
#
#                  Lon  GPS_Accu      Timestamp               IP OS_ID       OS  \
# ...

# %%
file.dtypes
# Out:
# Unnamed: 0                         int64
# Device_ID                         object
# Lat                              float64
# Lon                              float64
# GPS_Accu                         float64
# Timestamp                          int64
# IP                                object
# OS_ID                             object
# OS                                object
# Country                           object
# Quad_ID                            int64
# Publisher                         object
# Timestamp1                        object
# Timestamp2                        object
# AvantiID                          object
# TS_Central    datetime64[ns, US/Central]
# dtype: object

# %%
#Para pasar en formato date
#file['Timestamp2'] = file['Timestamp1'].values.astype('datetime64[D]')

#Lo queremos en formato str
file['TS_Text'] = file['TS_Central'].astype(str)
file
#file['TS_Text'] = file['TS_Text'].str[:10]
# Out:
#           Unnamed: 0                             Device_ID        Lat  \
# 0                  0  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593960
# 1                  1  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593920
# 2                  2  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515417
# 3                  3  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515432
# 4                  4  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515432
# ...              ...                                   ...        ...
# 13613812     1361638  bfe3d696-a67c-44e0-99a2-77748834c6eb  25.550000
# 13613813     1361639  bfe3d696-a67c-44e0-99a2-77748834c6eb  25.550000
# 13613814     1361640  34c1a55e-6f7e-406e-8399-55b674a1f76f  25.550000
# 13613815     1361641  d604ca18-b84d-47b0-8447-1c962ce6bbf6  25.550000
# 13613816     1361642  d604ca18-b84d-47b0-8447-1c962ce6bbf6  25.550000
#
#                  Lon  GPS_Accu      Timestamp               IP OS_ID       OS  \
# ...

# %%
file['AvantiID'] = file['Device_ID'] + '_' + file['TS_Text'].str[:10]
file
# Out:
#           Unnamed: 0                             Device_ID        Lat  \
# 0                  0  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593960
# 1                  1  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593920
# 2                  2  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515417
# 3                  3  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515432
# 4                  4  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515432
# ...              ...                                   ...        ...
# 13613812     1361638  bfe3d696-a67c-44e0-99a2-77748834c6eb  25.550000
# 13613813     1361639  bfe3d696-a67c-44e0-99a2-77748834c6eb  25.550000
# 13613814     1361640  34c1a55e-6f7e-406e-8399-55b674a1f76f  25.550000
# 13613815     1361641  d604ca18-b84d-47b0-8447-1c962ce6bbf6  25.550000
# 13613816     1361642  d604ca18-b84d-47b0-8447-1c962ce6bbf6  25.550000
#
#                  Lon  GPS_Accu      Timestamp               IP OS_ID       OS  \
# ...

# %%
#delte identicals
file_drop = file.drop_duplicates(subset=['Device_ID', 'Lat', 'Lon', 'Timestamp', 'OS'])
file_drop
# Out:
#           Unnamed: 0                             Device_ID        Lat  \
# 0                  0  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593960
# 1                  1  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593920
# 2                  2  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515417
# 3                  3  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515432
# 4                  4  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515432
# ...              ...                                   ...        ...
# 13613811     1361637  9510a7c7-4131-4b8c-85a4-2f55d4e370d2  25.550000
# 13613812     1361638  bfe3d696-a67c-44e0-99a2-77748834c6eb  25.550000
# 13613814     1361640  34c1a55e-6f7e-406e-8399-55b674a1f76f  25.550000
# 13613815     1361641  d604ca18-b84d-47b0-8447-1c962ce6bbf6  25.550000
# 13613816     1361642  d604ca18-b84d-47b0-8447-1c962ce6bbf6  25.550000
#
#                  Lon  GPS_Accu      Timestamp               IP OS_ID       OS  \
# ...

# %%
file_drop.to_csv(r'F:\Quadrant\Procesos\DescargasBigQuery\20210528_Torreon_Matamoros\Originales\uadrant_Torreon_Matamoros_20210528_parte000000000000.csv_CT_Clean.csv')

# %% [markdown]
# ## Proecesamiento para eliminar Device_ID identicos

# %%
#delte identicals
file_drop_ID = file.drop_duplicates(subset=['Device_ID'])
file_drop_ID
# Out:
#           Unnamed: 0                             Device_ID        Lat  \
# 0                  0  1f90f869-ed97-47ec-8f56-28b5adf8e382  25.593960
# 2                  2  06e6e882-4fd0-4aad-b582-a7677b6e9b53  25.515417
# 16                16  121880cb-b81a-4ce9-8cd1-18d2ef7c8243  25.561676
# 17                17  862a87fa-2a74-4c4f-a267-e99a1af37b8f  25.573130
# 18                18  db117904-ca26-462d-ab4f-ecf3e90f7ba1  25.585587
# ...              ...                                   ...        ...
# 13612081     1359907  b31f2b18-e31d-4805-8bb2-ef8f32f76a8e  25.689400
# 13612174     1360000  aed7bbac-0e17-40b7-9d55-00326a82b4af  25.550000
# 13612354     1360180  f72310a1-2b1d-44f9-84e8-b9254743fefd  25.549000
# 13612413     1360239  487f8452-5872-44e4-ad96-0da2c6e6dd94  25.575200
# 13612602     1360428  2417b13c-5536-451a-a23c-9f53b4da2180  25.550000
#
#                 Lon  GPS_Accu      Timestamp               IP OS_ID       OS  \
# ...

# %%
file_drop_ID.to_csv(r'F:\Quadrant\Procesos\DescargasBigQuery\20210528_Torreon_Matamoros\Originales\uadrant_Torreon_Matamoros_20210528_parte000000000000.csv_CT_clean_UniVal.csv')

# %%
file.dtypes
# Out:
# Device_ID             object
# Lat                  float64
# Lon                  float64
# GPS_Accu             float64
# Timestamp              int64
# IP                    object
# OS_ID                 object
# OS                    object
# Country               object
# Quad_ID                int64
# Publisher             object
# Timestamp1    datetime64[ns]
# Timestamp2            object
# AvantiID              object
# dtype: object
