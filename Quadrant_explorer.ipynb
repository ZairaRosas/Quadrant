# %%
import pandas as pd
from pandas import read_csv

# %%
file = read_csv(r'E:\Quadrant_Sin_comprimir\02\part-00000-c6da3795-1b1c-4509-bfa7-0de1833d6b1a-c000.csv', names = ['Device_ID', 'Lat', 'Lon', 'GPS_Accu', 'Timestamp', 'IP', 'OS_ID', 'OS', 'Country', 'Quad_ID', 'Publisher'])
file
# Out:
#                                      Device_ID        Lat         Lon  \
# 0         0EED4050-5117-4BC8-AB2D-6504FB5E9BA9  25.946060  -97.468150
# 1         8ded0000-66e2-4854-99d8-860a24eb7043  38.722200  -77.107400
# 2         daf49549-bf67-4f33-a727-9fbe4bccfa6a  39.916622  -85.387070
# 3         C779F7A2-4139-44C5-AF31-512D7CD13210  41.168198  -73.268900
# 4         ec0dba7e-7e25-4482-84e2-0e6d3465f51f  34.216217 -118.599020
# ...                                        ...        ...         ...
# 14117156  1456e60d-eaff-4113-9ec3-e8031b5ef2b3  32.236397 -110.928604
# 14117157  9067afaa-fe20-4fe8-8190-748306dc2f80  20.671190  -87.050310
# 14117158  9eb5a77f-9c59-4d57-b164-a4c5059213b3  37.052788  -76.498140
# 14117159  e360e0ea-cab0-487e-9c18-c4e2e90e0268  35.337753  -80.852140
# 14117160  52bb3775-975a-4db5-9182-c499f83038d2  20.537750 -100.462640
#
#           GPS_Accu      Timestamp              IP OS_ID       OS Country  \
# 0              6.0  1569480606000  172.58.101.127  idfa      iOS      US
# 1           4811.0  1569480606000  96.255.244.230  aaid  Android      US
# 2             19.0  1569480606000   99.203.78.197  aaid  Android      US
# 3              4.0  1569480607000    67.81.251.92  idfa      iOS      US
# 4           1316.0  1569480607000    69.75.177.51  aaid  Android      US
# ...            ...            ...             ...   ...      ...     ...
# 14117156       5.0  1570047314000             NaN  aaid  Android      US
# 14117157      11.0  1570047315000             NaN  aaid  Android      MX
# 14117158      21.0  1570047317000             NaN  aaid  Android      US
# 14117159      18.0  1570047317000             NaN  aaid  Android      US
# 14117160      30.0  1570047318000             NaN  aaid  Android      MX
#
#           Quad_ID                         Publisher
# 0              24  ebd8eceafe1479f86f75e2f54d6aac77
# 1              24  ebd8eceafe1479f86f75e2f54d6aac77
# 2              24  ebd8eceafe1479f86f75e2f54d6aac77
# 3              24  ebd8eceafe1479f86f75e2f54d6aac77
# 4              24  ebd8eceafe1479f86f75e2f54d6aac77
# ...           ...                               ...
# 14117156       24  907602dad23f9b70a59dbfe7c62f0be1
# 14117157       24  907602dad23f9b70a59dbfe7c62f0be1
# 14117158       24  907602dad23f9b70a59dbfe7c62f0be1
# 14117159       24  907602dad23f9b70a59dbfe7c62f0be1
# 14117160       24  907602dad23f9b70a59dbfe7c62f0be1
#
# [14117161 rows x 11 columns]

# %%
#verificar si el archivo tiene datos del mismo devide

unique_values_Did =  file.Device_ID.value_counts()
unique_values_Did
# Out:
# 7FB3AE1C-FA3A-4E8D-9C44-A6BCF59C1F81    16771
# 7fb3ae1c-fa3a-4e8d-9c44-a6bcf59c1f81      791
# f4b3633f-ddff-4701-ac5f-ed452a15dfcc      336
# a9066628-b482-438a-a8e1-4777b8a47faa      304
# 6f314ba2-2d59-414e-adf3-52834b4e76de      299
#                                         ...
# 501B1597-ECF0-48D8-9C0E-138714154035        1
# E6C7C24E-D329-4059-AA91-9B1BCD1410BA        1
# 0533581c-b2c4-45dc-bcd6-971a5becc051        1
# a487f689-a55d-4928-ba06-a2c0486a6b0e        1
# 3F23E50C-1041-449C-B1A2-6E1A0BE73C27        1
# Name: Device_ID, Length: 3966111, dtype: int64

# %%
#prueba con el device que más se repite

file = file[(file['Device_ID'] == '7FB3AE1C-FA3A-4E8D-9C44-A6BCF59C1F81') & (file['Device_ID'] == '7FB3AE1C-FA3A-4E8D-9C44-A6BCF59C1F81')]
file.sort_values(by='Timestamp1', ascending=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-5cd9dae3304e> in <module>
#       2
#       3 file = file[(file['Device_ID'] == '7FB3AE1C-FA3A-4E8D-9C44-A6BCF59C1F81')]
# ----> 4 file.sort_values(by='Timestamp1', ascending=True)
#
# c:\python37\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index)
#    4925
#    4926             by = by[0]
# -> 4927             k = self._get_label_or_level_values(by, axis=axis)
#    4928
#    4929             if isinstance(ascending, (tuple, list)):
#
# c:\python37\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'Timestamp1'
