# %% [markdown]
# <h1>Proecso para 10 archivos de Quadrant al mismo tiempo<h1>

# %%
import pandas as pd
from pandas import read_csv
import geopandas as gpd

# %%
df00 = read_csv(r'D:\2021\QUADRANT\BD\MX_Quadrant_MX_02_parte000000000051.csv')

# %%
df = pd.concat([df00, df01, df02, df03, df04, df05, df06, df07, df08, df09])
df

# %%
df['Timestamp1'] = df['Timestamp'].astype(str)
df['Timestamp1'] = df['Timestamp1'].str[:10]
df['Timestamp1'] = pd.to_datetime(df['Timestamp1'], unit='s')
df
# Out:
#                                     Device_ID        Lat         Lon  \
# 0        0b3e509b-9e42-461d-b0e9-2c8b516dd55c  32.446100 -117.026300
# 1        6695f9e6-34c5-45bf-bcb8-0d621805dfe1  22.170052 -100.938420
# 2        47236390-7424-4dfe-a7f8-9f8d9ba70a7b  32.405907 -116.969640
# 3        6046c6f6-b055-4e0e-888d-f2120b850caa  25.667770 -100.257920
# 4        5f41c050-0435-441a-b4e8-0e41bb36c67f  19.548801  -99.206250
# ...                                       ...        ...         ...
# 5807124  3552bc45-a90a-41c7-a954-20a16348ea5b  21.957998 -102.336266
# 5807125  51AD7E09-CDBA-4F05-B5D4-DA8DD4EDC186  19.514952  -99.047500
# 5807126  A329FBB9-CFED-4DA8-AC66-1BF8B7CA3F8B  25.708050 -100.269730
# 5807127  5e3cfebd-e00d-4101-85ea-f903fa81ae5a  19.338243  -99.099840
# 5807128  1d1513e1-b9c3-4dad-babd-6f59f243514e  19.326365  -99.213440
#
#          GPS_Accu      Timestamp               IP OS_ID       OS Country  \
# 0         2186.00  1570491244000   200.68.175.134  aaid  Android      MX
# 1            9.00  1570488179000   189.183.61.117  aaid  Android      MX
# 2           16.00  1570491624000   177.236.63.100  aaid  Android      MX
# 3            6.00  1570488546000    200.68.140.28  aaid  Android      MX
# 4           22.00  1570491060000    187.237.25.11  aaid  Android      MX
# ...           ...            ...              ...   ...      ...     ...
# 5807124      4.29  1570503124000  187.232.179.227  aaid  Android      MX
# 5807125     59.82  1570503126000   201.157.84.129  idfa      iOS      MX
# 5807126     16.01  1570502811000    187.160.9.218  idfa      iOS      MX
# 5807127      6.44  1570502813000    200.68.128.13  aaid  Android      MX
# 5807128      3.30  1570502814000   189.216.51.206  aaid  Android      MX
#
#          Quad_ID                                          Publisher  \
# 0             30  9d47265cb8860dda06c6d3d99b4f912d28edc9313297c5...
# 1             30  547fee13195db32780cdf504a01cf9a81bf0b517cf1687...
# 2             30  547fee13195db32780cdf504a01cf9a81bf0b517cf1687...
# 3             30  249ec3ba8e29ef683af96647be648122154805a79225f8...
# 4             30  f1298a9ace5dca173a039b7080232133573c9d6f723362...
# ...          ...                                                ...
# 5807124       16                                60_2a536d6ffd39f4e4
# 5807125       16                                60_2a536d6ffd39f4e4
# 5807126       16                                60_2a536d6ffd39f4e4
# 5807127       16                                60_2a536d6ffd39f4e4
# 5807128       16                                60_2a536d6ffd39f4e4
#
#                  Timestamp1
# 0       2019-10-07 23:34:04
# 1       2019-10-07 22:42:59
# 2       2019-10-07 23:40:24
# 3       2019-10-07 22:49:06
# 4       2019-10-07 23:31:00
# ...                     ...
# 5807124 2019-10-08 02:52:04
# 5807125 2019-10-08 02:52:06
# 5807126 2019-10-08 02:46:51
# 5807127 2019-10-08 02:46:53
# 5807128 2019-10-08 02:46:54
#
# [5807129 rows x 12 columns]

# %%
#Para pasar en formato date hasta el día
df['Timestamp2'] = df['Timestamp1'].values.astype('datetime64[D]')

#Lo queremos en formato str
df['Timestamp2'] = df['Timestamp1'].astype(str)
df['Timestamp2'] = df['Timestamp2'].str[:10]
df
# Out:
#                                     Device_ID        Lat         Lon  \
# 0        0b3e509b-9e42-461d-b0e9-2c8b516dd55c  32.446100 -117.026300
# 1        6695f9e6-34c5-45bf-bcb8-0d621805dfe1  22.170052 -100.938420
# 2        47236390-7424-4dfe-a7f8-9f8d9ba70a7b  32.405907 -116.969640
# 3        6046c6f6-b055-4e0e-888d-f2120b850caa  25.667770 -100.257920
# 4        5f41c050-0435-441a-b4e8-0e41bb36c67f  19.548801  -99.206250
# ...                                       ...        ...         ...
# 5807124  3552bc45-a90a-41c7-a954-20a16348ea5b  21.957998 -102.336266
# 5807125  51AD7E09-CDBA-4F05-B5D4-DA8DD4EDC186  19.514952  -99.047500
# 5807126  A329FBB9-CFED-4DA8-AC66-1BF8B7CA3F8B  25.708050 -100.269730
# 5807127  5e3cfebd-e00d-4101-85ea-f903fa81ae5a  19.338243  -99.099840
# 5807128  1d1513e1-b9c3-4dad-babd-6f59f243514e  19.326365  -99.213440
#
#          GPS_Accu      Timestamp               IP OS_ID       OS Country  \
# 0         2186.00  1570491244000   200.68.175.134  aaid  Android      MX
# 1            9.00  1570488179000   189.183.61.117  aaid  Android      MX
# 2           16.00  1570491624000   177.236.63.100  aaid  Android      MX
# 3            6.00  1570488546000    200.68.140.28  aaid  Android      MX
# 4           22.00  1570491060000    187.237.25.11  aaid  Android      MX
# ...           ...            ...              ...   ...      ...     ...
# 5807124      4.29  1570503124000  187.232.179.227  aaid  Android      MX
# 5807125     59.82  1570503126000   201.157.84.129  idfa      iOS      MX
# 5807126     16.01  1570502811000    187.160.9.218  idfa      iOS      MX
# 5807127      6.44  1570502813000    200.68.128.13  aaid  Android      MX
# 5807128      3.30  1570502814000   189.216.51.206  aaid  Android      MX
#
#          Quad_ID                                          Publisher  \
# 0             30  9d47265cb8860dda06c6d3d99b4f912d28edc9313297c5...
# 1             30  547fee13195db32780cdf504a01cf9a81bf0b517cf1687...
# 2             30  547fee13195db32780cdf504a01cf9a81bf0b517cf1687...
# 3             30  249ec3ba8e29ef683af96647be648122154805a79225f8...
# 4             30  f1298a9ace5dca173a039b7080232133573c9d6f723362...
# ...          ...                                                ...
# 5807124       16                                60_2a536d6ffd39f4e4
# 5807125       16                                60_2a536d6ffd39f4e4
# 5807126       16                                60_2a536d6ffd39f4e4
# 5807127       16                                60_2a536d6ffd39f4e4
# 5807128       16                                60_2a536d6ffd39f4e4
#
#                  Timestamp1  Timestamp2
# 0       2019-10-07 23:34:04  2019-10-07
# 1       2019-10-07 22:42:59  2019-10-07
# 2       2019-10-07 23:40:24  2019-10-07
# 3       2019-10-07 22:49:06  2019-10-07
# 4       2019-10-07 23:31:00  2019-10-07
# ...                     ...         ...
# 5807124 2019-10-08 02:52:04  2019-10-08
# 5807125 2019-10-08 02:52:06  2019-10-08
# 5807126 2019-10-08 02:46:51  2019-10-08
# 5807127 2019-10-08 02:46:53  2019-10-08
# 5807128 2019-10-08 02:46:54  2019-10-08
#
# [5807129 rows x 13 columns]

# %%
df['AvantiID'] = df['Device_ID'] + df['Timestamp2']
df
# Out:
#                                     Device_ID        Lat         Lon  \
# 0        0b3e509b-9e42-461d-b0e9-2c8b516dd55c  32.446100 -117.026300
# 1        6695f9e6-34c5-45bf-bcb8-0d621805dfe1  22.170052 -100.938420
# 2        47236390-7424-4dfe-a7f8-9f8d9ba70a7b  32.405907 -116.969640
# 3        6046c6f6-b055-4e0e-888d-f2120b850caa  25.667770 -100.257920
# 4        5f41c050-0435-441a-b4e8-0e41bb36c67f  19.548801  -99.206250
# ...                                       ...        ...         ...
# 5807124  3552bc45-a90a-41c7-a954-20a16348ea5b  21.957998 -102.336266
# 5807125  51AD7E09-CDBA-4F05-B5D4-DA8DD4EDC186  19.514952  -99.047500
# 5807126  A329FBB9-CFED-4DA8-AC66-1BF8B7CA3F8B  25.708050 -100.269730
# 5807127  5e3cfebd-e00d-4101-85ea-f903fa81ae5a  19.338243  -99.099840
# 5807128  1d1513e1-b9c3-4dad-babd-6f59f243514e  19.326365  -99.213440
#
#          GPS_Accu      Timestamp               IP OS_ID       OS Country  \
# 0         2186.00  1570491244000   200.68.175.134  aaid  Android      MX
# 1            9.00  1570488179000   189.183.61.117  aaid  Android      MX
# 2           16.00  1570491624000   177.236.63.100  aaid  Android      MX
# 3            6.00  1570488546000    200.68.140.28  aaid  Android      MX
# 4           22.00  1570491060000    187.237.25.11  aaid  Android      MX
# ...           ...            ...              ...   ...      ...     ...
# 5807124      4.29  1570503124000  187.232.179.227  aaid  Android      MX
# 5807125     59.82  1570503126000   201.157.84.129  idfa      iOS      MX
# 5807126     16.01  1570502811000    187.160.9.218  idfa      iOS      MX
# 5807127      6.44  1570502813000    200.68.128.13  aaid  Android      MX
# 5807128      3.30  1570502814000   189.216.51.206  aaid  Android      MX
#
#          Quad_ID                                          Publisher  \
# 0             30  9d47265cb8860dda06c6d3d99b4f912d28edc9313297c5...
# 1             30  547fee13195db32780cdf504a01cf9a81bf0b517cf1687...
# 2             30  547fee13195db32780cdf504a01cf9a81bf0b517cf1687...
# 3             30  249ec3ba8e29ef683af96647be648122154805a79225f8...
# 4             30  f1298a9ace5dca173a039b7080232133573c9d6f723362...
# ...          ...                                                ...
# 5807124       16                                60_2a536d6ffd39f4e4
# 5807125       16                                60_2a536d6ffd39f4e4
# 5807126       16                                60_2a536d6ffd39f4e4
# 5807127       16                                60_2a536d6ffd39f4e4
# 5807128       16                                60_2a536d6ffd39f4e4
#
#                  Timestamp1  Timestamp2  \
# 0       2019-10-07 23:34:04  2019-10-07
# 1       2019-10-07 22:42:59  2019-10-07
# 2       2019-10-07 23:40:24  2019-10-07
# 3       2019-10-07 22:49:06  2019-10-07
# 4       2019-10-07 23:31:00  2019-10-07
# ...                     ...         ...
# 5807124 2019-10-08 02:52:04  2019-10-08
# 5807125 2019-10-08 02:52:06  2019-10-08
# 5807126 2019-10-08 02:46:51  2019-10-08
# 5807127 2019-10-08 02:46:53  2019-10-08
# 5807128 2019-10-08 02:46:54  2019-10-08
#
#                                                AvantiID
# 0        0b3e509b-9e42-461d-b0e9-2c8b516dd55c2019-10-07
# 1        6695f9e6-34c5-45bf-bcb8-0d621805dfe12019-10-07
# 2        47236390-7424-4dfe-a7f8-9f8d9ba70a7b2019-10-07
# 3        6046c6f6-b055-4e0e-888d-f2120b850caa2019-10-07
# 4        5f41c050-0435-441a-b4e8-0e41bb36c67f2019-10-07
# ...                                                 ...
# 5807124  3552bc45-a90a-41c7-a954-20a16348ea5b2019-10-08
# 5807125  51AD7E09-CDBA-4F05-B5D4-DA8DD4EDC1862019-10-08
# 5807126  A329FBB9-CFED-4DA8-AC66-1BF8B7CA3F8B2019-10-08
# 5807127  5e3cfebd-e00d-4101-85ea-f903fa81ae5a2019-10-08
# 5807128  1d1513e1-b9c3-4dad-babd-6f59f243514e2019-10-08
#
# [5807129 rows x 14 columns]

# %%
df.to_csv(r'C:\Quadrant_DespuesModel\Partes\01\Quadrant_MX_01_p1.csv')
