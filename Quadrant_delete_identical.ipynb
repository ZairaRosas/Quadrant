# %%
from pandas import read_csv

# %%
file = read_csv(r'F:\Quadrant\Procesos\DescargasBigQuery\20210528_Torreon_Matamoros\DespuesPython\Quadrant_Torreon_clean.csv')
file
# Out:
#          Unnamed: 0  Unnamed: 0.1                             Device_ID  \
# 0                 0             0  1f90f869-ed97-47ec-8f56-28b5adf8e382
# 1                 1             1  1f90f869-ed97-47ec-8f56-28b5adf8e382
# 2                 2             2  06e6e882-4fd0-4aad-b582-a7677b6e9b53
# 3                 3             3  06e6e882-4fd0-4aad-b582-a7677b6e9b53
# 4                 4             4  06e6e882-4fd0-4aad-b582-a7677b6e9b53
# ...             ...           ...                                   ...
# 8811982    13613811       1361637  9510a7c7-4131-4b8c-85a4-2f55d4e370d2
# 8811983    13613812       1361638  bfe3d696-a67c-44e0-99a2-77748834c6eb
# 8811984    13613814       1361640  34c1a55e-6f7e-406e-8399-55b674a1f76f
# 8811985    13613815       1361641  d604ca18-b84d-47b0-8447-1c962ce6bbf6
# 8811986    13613816       1361642  d604ca18-b84d-47b0-8447-1c962ce6bbf6
#
#                Lat         Lon  GPS_Accu      Timestamp               IP  \
# ...

# %%
file.loc[file['Timestamp'] == 0]
# Out:
#          Unnamed: 0  Unnamed: 0.1                             Device_ID  \
# 549165       554862        554862  D0F20FE2-10C6-438A-A5C5-4DD8EC978B57
# 2777891     3063012        339708  D0F20FE2-10C6-438A-A5C5-4DD8EC978B57
# 4824138     5786112        339435  D0F20FE2-10C6-438A-A5C5-4DD8EC978B57
# 5785883     7258102        449970  D0F20FE2-10C6-438A-A5C5-4DD8EC978B57
# 5819555     7300419        492287  D0F20FE2-10C6-438A-A5C5-4DD8EC978B57
# 6514623     8518439        350464  D0F20FE2-10C6-438A-A5C5-4DD8EC978B57
# 7228534     9880190        351315  D0F20FE2-10C6-438A-A5C5-4DD8EC978B57
# 7346754    10063174        534299  5AD92795-2F48-465F-AF7A-448763710FB2
# 7883402    11291671        402128  D0F20FE2-10C6-438A-A5C5-4DD8EC978B57
# 8196486    11872949        983406  5AD92795-2F48-465F-AF7A-448763710FB2
# 8400240    12556262        304088  5AD92795-2F48-465F-AF7A-448763710FB2
# 8494756    12748580        496406  D0F20FE2-10C6-438A-A5C5-4DD8EC978B57
#
# ...

# %%
file_drop.sort_values(by='Device_ID')
# Out:
#          Unnamed: 0  Unnamed: 0.1                             Device_ID  \
# 222054       224175        224175  000027de-e6a7-4748-a8f3-e5e1f320d9e3
# 2379377     2571009       1209145  000073b8-97db-4b21-9e4f-f18782ae65e5
# 233850       236088        236088  00010D52-9071-4789-A637-97E7EA4A843C
# 17835         17880         17880  00010d52-9071-4789-a637-97e7ea4a843c
# 1251103     1301390       1301390  00012e46-d018-4e83-a70a-9b98b254ccc7
# ...             ...           ...                                   ...
# 45167         45364         45364  fffd2862-bdbd-498d-959c-1cf0dd39782f
# 911388       933578        933578  fffdc032-d5ec-4abc-8d4d-2c966b7e1001
# 1361669     1424112         62248  fffddfc5-a311-4c46-a3b7-5fb27b17ea77
# 326604       330281        330281  fffe3cab-9591-4b14-918a-03c5e8be17bf
# 815661       831795        831795  ffff5297-078e-4a52-bda5-9a87c68ac8ea
#
#                Lat        Lon  GPS_Accu      Timestamp               IP OS_ID  \
# ...

# %%
file_drop = file.drop_duplicates(subset=['Device_ID', 'Lat', 'Lon', 'Timestamp', 'OS'])
file_drop

# %%
df01.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191001.csv')
df02 = file_drop[file_drop['Timestamp2'] == '2019-10-02']
df03 = file_drop[file_drop['Timestamp2'] == '2019-10-03']
df04 = file_drop[file_drop['Timestamp2'] == '2019-10-04']
df05 = file_drop[file_drop['Timestamp2'] == '2019-10-05']
df06 = file_drop[file_drop['Timestamp2'] == '2019-10-06']
df07 = file_drop[file_drop['Timestamp2'] == '2019-10-07']
df08 = file_drop[file_drop['Timestamp2'] == '2019-10-08']
df09 = file_drop[file_drop['Timestamp2'] == '2019-10-09']
df10 = file_drop[file_drop['Timestamp2'] == '2019-10-10']
df11 = file_drop[file_drop['Timestamp2'] == '2019-10-11']
df12 = file_drop[file_drop['Timestamp2'] == '2019-10-12']
df13 = file_drop[file_drop['Timestamp2'] == '2019-10-13']
df14 = file_drop[file_drop['Timestamp2'] == '2019-10-14']
df15 = file_drop[file_drop['Timestamp2'] == '2019-10-15']
df16 = file_drop[file_drop['Timestamp2'] == '2019-10-16']
df17 = file_drop[file_drop['Timestamp2'] == '2019-10-17']
df18 = file_drop[file_drop['Timestamp2'] == '2019-10-18']
df19 = file_drop[file_drop['Timestamp2'] == '2019-10-19']
df20 = file_drop[file_drop['Timestamp2'] == '2019-10-20']
df21 = file_drop[file_drop['Timestamp2'] == '2019-10-21']
df22 = file_drop[file_drop['Timestamp2'] == '2019-10-22']
df23 = file_drop[file_drop['Timestamp2'] == '2019-10-23']
df24 = file_drop[file_drop['Timestamp2'] == '2019-10-24']
df25 = file_drop[file_drop['Timestamp2'] == '2019-10-25']
df26 = file_drop[file_drop['Timestamp2'] == '2019-10-26']
df27 = file_drop[file_drop['Timestamp2'] == '2019-10-27']
df28 = file_drop[file_drop['Timestamp2'] == '2019-10-28']
df29 = file_drop[file_drop['Timestamp2'] == '2019-10-29']
df30 = file_drop[file_drop['Timestamp2'] == '2019-10-30']
df31 = file_drop[file_drop['Timestamp2'] == '2019-10-31']

# %%
df01.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191001.csv')
df02.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191002.csv')
df03.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191003.csv')
df04.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191004.csv')
df05.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191005.csv')
df06.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191006.csv')
df07.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191007.csv')
df08.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191008.csv')
df09.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191009.csv')
df10.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191010.csv')
df11.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191011.csv')
df12.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191012.csv')
df13.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191013.csv')
df14.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191014.csv')
df15.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191015.csv')
df16.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191016.csv')
df17.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191017.csv')
df18.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191018.csv')
df19.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191019.csv')
df20.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191020.csv')
df21.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191021.csv')
df22.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191022.csv')
df23.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191023.csv')
df24.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191024.csv')
df25.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191025.csv')
df26.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191026.csv')
df27.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191027.csv')
df28.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191028.csv')
df29.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191029.csv')
df30.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191030.csv')
df31.to_csv(r'E:\Procesos\SHP\Quadrant_Torreon\Quadrant_Torreon_20191031.csv')
