# %%
import pandas as pd
import geopandas as gpd
from pandas import read_csv
from geopandas import GeoDataFrame, points_from_xy
from shapely import wkt
from geopandas.tools import sjoin

# %% [markdown]
# ### Tabla de AGEBS categorizados

# %%
gdf_id_finals= gpd.read_file(r'F:\Quadrant\Procesos\SHP\Acuña_DelRio\id_finals.shp')
gdf_id_finals
# Out:
#                                 Device_ID         Lon        Lat  Tot3am  \
# 0    001d10b5-8b69-41fb-87a8-9deb66f8420c -100.961050  29.304188       1
# 1    001f148c-69fa-48fd-9182-d2758849e4cb -100.963356  29.323298      24
# 2    00660619-EA70-45D7-8257-238AAF0A3814 -100.945430  29.298666     307
# 3    00660619-ea70-45d7-8257-238aaf0a3814 -100.945430  29.298666    1133
# 4    00aa79ed-2f4e-46c7-bd9a-922263f1c54a -100.949530  29.313904     133
# ..                                    ...         ...        ...     ...
# 392  fe8ae606-82e2-462d-a703-8475ee083057 -100.943200  29.324200       1
# 393  fe961488-3ba2-4b0e-80b1-3c694388fefa -100.944760  29.308323      54
# 394  ff1175ad-e2f3-4c14-84e3-a72f05245d75 -100.959430  29.302135      57
# 395  ff540a70-d170-4a60-b596-6a578a13a5e4 -100.965890  29.315315      46
# 396  ffd2702c-064d-442b-be4d-1d1f4370ed86 -100.964540  29.306694       1
#
#      Total      Indice                     geometry
# ...

# %%
gdf_agebs = gpd.read_file(r'F:\Quadrant\Procesos\SHP\Acuña_DelRio\AGEBs_JOIN\05a_JOIN_wgs.shp')
gdf_agebs
# Out:
#       FID_1         CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  \
# 0         0  0500100010087      05     001    0001     0087
# 1         1  0500200011561      05     002    0001     1561
# 2         2  0500200012926      05     002    0001     2926
# 3         3  0500200013407      05     002    0001     3407
# 4         4  050020001313A      05     002    0001     313A
# ...     ...            ...     ...     ...     ...      ...
# 1877   1877  0500400010106      05     004    0001     0106
# 1878   1878  0500400010515      05     004    0001     0515
# 1879   1879  0500400010055      05     004    0001     0055
# 1880   1880  050040107013A      05     004    0107     013A
# 1881   1881  0500401070534      05     004    0107     0534
#
#                    NOM_ENT  NOM_MUN            NOM_LOC  POBTOT  ...  \
# 0     Coahuila de Zaragoza  Abasolo  Total AGEB urbana   735.0  ...
# 1     Coahuila de Zaragoza    Acuña  Total AGEB urbana  2443.0  ...
# ...

# %%
sjoin_agebs = sjoin(gdf_id_finals, gdf_agebs, how="inner", op="intersects")
sjoin_agebs
# Out:
#                                 Device_ID         Lon        Lat  Tot3am  \
# 0    001d10b5-8b69-41fb-87a8-9deb66f8420c -100.961050  29.304188       1
# 15   07e4a80f-3889-405a-9ae2-92fd1b0ef97d -100.959270  29.303543       5
# 38   181df606-2548-46df-aae3-d8826fffd052 -100.960266  29.303953      23
# 41   19520100-c351-4172-90b3-50b2197d4b6c -100.959000  29.303658       4
# 42   1B940568-65D2-4169-BD8C-5BA79CA817C1 -100.962130  29.306618     569
# ..                                    ...         ...        ...     ...
# 299  bfd2fa7b-d1eb-4f62-b623-50fdb4b81e31 -100.956180  29.307770       2
# 306  c5a6d237-d5db-49d2-b93e-937c995aee1a -100.944550  29.331380      33
# 357  e8b80120-a086-4123-88de-72fc01441905 -100.939720  29.330536     123
# 349  e4a629f7-60fc-4c81-8e48-c8442fa4345e -100.948160  29.292890      25
# 393  fe961488-3ba2-4b0e-80b1-3c694388fefa -100.944760  29.308323      54
#
#      Total      Indice                     geometry  index_right  FID_1  \
# ...
